# %%
import pandas as pd

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv(r"C:\Users\elham\Desktop\excel2\Ionosphere.csv")

# %%
df.head()
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10  ...      V26      V27      V28      V29      V30      V31  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        V32      V33      V34  Class
# 0 -0.54487  0.18641 -0.45300      1
# ...

# %%
x,y=df.iloc[:,:-1],df.iloc[:,-1]

# %%
x.head(2)
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8   V9      V10  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.0  0.03760
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.0 -0.04549
#
#    ...      V25      V26      V27      V28      V29      V30      V31  \
# 0  ...  0.56811 -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1  ... -0.20332 -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
#
#        V32      V33      V34
# 0 -0.54487  0.18641 -0.45300
# 1 -0.06288 -0.13738 -0.02447
#
# [2 rows x 34 columns]

# %%
y.head(2)
# Out:
# 0    1
# 1    0
# Name: Class, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      351 non-null    int64
#  1   V2      351 non-null    int64
#  2   V3      351 non-null    float64
#  3   V4      351 non-null    float64
#  4   V5      351 non-null    float64
#  5   V6      351 non-null    float64
#  6   V7      351 non-null    float64
#  7   V8      351 non-null    float64
#  8   V9      351 non-null    float64
#  9   V10     351 non-null    float64
#  10  V11     351 non-null    float64
#  11  V12     351 non-null    float64
#  12  V13     351 non-null    float64
#  13  V14     351 non-null    float64
#  14  V15     351 non-null    float64
#  15  V16     351 non-null    float64
#  16  V17     351 non-null    float64
#  17  V18     351 non-null    float64
#  18  V19     351 non-null    float64
#  19  V20     351 non-null    float64
#  20  V21     351 non-null    float64
# ...

# %%
#if y was not int , you could label all y as int 
# y=LabelEncoder().fit_transform(y)
#
# Encode the labels
#encoder = LabelEncoder()
#y_encoded = encoder.fit_transform(y)

# %%
#Most deep learning frameworks (e.g., TensorFlow, PyTorch) use float32 as the default precision for computations. 
#Converting your data to float32 ensures compatibility and prevents unnecessary type-casting overhead.
x=x.astype('float32')

# %%
x.shape
# Out:
# (351, 34)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33)

# %%
x_train.shape
# Out:
# (235, 34)

# %%
n_feature=x_train.shape[1]
n_feature
# Out:
# 34

# %%
model=Sequential()
model.add(Dense(10,activation='relu',kernel_initializer='he_normal',input_shape=(n_feature,)))
model.add(Dense(8,activation='relu',kernel_initializer='he_normal'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=150,batch_size=30,verbose=0)

# %%
#astype(float32)
#normalization /255
#output int, LabelEncder 
#flatten

# %%
model.fit(x_train,y_train,epochs=150,batch_size=30,verbose=1)
# Out:
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9776 - loss: 0.0507
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9851 - loss: 0.0558
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9872 - loss: 0.0327
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9903 - loss: 0.0390
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9819 - loss: 0.0416
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9847 - loss: 0.0430
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9788 - loss: 0.0446
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9933 - loss: 0.0290
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9885 - loss: 0.0382
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9885 - loss: 0.0566
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9907 - loss: 0.0360
# Epoch 12/150
# ...

# %%
model.fit(x_train,y_train,epochs=150,batch_size=30,verbose=2)
# Out:
# Epoch 1/150
# 8/8 - 0s - 10ms/step - accuracy: 0.9957 - loss: 0.0198
# Epoch 2/150
# 8/8 - 0s - 11ms/step - accuracy: 0.9957 - loss: 0.0196
# Epoch 3/150
# 8/8 - 0s - 12ms/step - accuracy: 0.9957 - loss: 0.0195
# Epoch 4/150
# 8/8 - 0s - 12ms/step - accuracy: 0.9957 - loss: 0.0195
# Epoch 5/150
# 8/8 - 0s - 11ms/step - accuracy: 0.9957 - loss: 0.0192
# Epoch 6/150
# 8/8 - 0s - 24ms/step - accuracy: 0.9957 - loss: 0.0195
# Epoch 7/150
# 8/8 - 0s - 12ms/step - accuracy: 0.9957 - loss: 0.0205
# Epoch 8/150
# 8/8 - 0s - 12ms/step - accuracy: 0.9957 - loss: 0.0195
# Epoch 9/150
# 8/8 - 0s - 11ms/step - accuracy: 0.9957 - loss: 0.0188
# Epoch 10/150
# 8/8 - 0s - 9ms/step - accuracy: 0.9957 - loss: 0.0191
# Epoch 11/150
# 8/8 - 0s - 10ms/step - accuracy: 0.9957 - loss: 0.0185
# Epoch 12/150
# 8/8 - 0s - 11ms/step - accuracy: 0.9957 - loss: 0.0195
# Epoch 13/150
# 8/8 - 0s - 12ms/step - accuracy: 0.9957 - loss: 0.0189
# Epoch 14/150
# 8/8 - 0s - 11ms/step - accuracy: 0.9957 - loss: 0.0187
# ...

# %%
y_predect=model.predict(x_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
y_predect[0]
# Out:
# array([0.99975383], dtype=float32)

# %%
y_test[0]
# Out:
# 1
